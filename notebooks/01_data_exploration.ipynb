# %%
import pandas as pd 

commandes = pd.read_excel("../data/raw/commandes.xlsx")
lignes = pd.read_excel("../data/raw/lignes.xlsx")
gps = pd.read_excel("../data/raw/gps.xlsx")

for name,df in [("commandes" , commandes) , ("lignes" , lignes) , ("gps" , gps)] :
    print(f"--- {name} ---")
    print(df.shape)
    print(df.dtypes)
    print(df.isna().sum())
    print(df.head(3))
    print()
# Out:
# --- commandes ---
# (18444, 5)
# No_                 str
# client_code         str
# Posting Date        str
# Salesperson Code    str
# company             str
# dtype: object
# No_                 0
# client_code         0
# Posting Date        0
# Salesperson Code    0
# company             0
# dtype: int64
#              No_ client_code             Posting Date Salesperson Code company
# 0  V24-FAC+00002   CLT082902  2024-01-08 00:00:00.000               SE    LSAT
# 1  V24-FAC+00003   CLT058599  2024-01-08 00:00:00.000               KO    LSAT
# 2  V24-FAC+00004   CLT097966  2024-01-08 00:00:00.000               ML    LSAT
#
# --- lignes ---
# (78720, 6)
# Document No_              str
# Quantity                int64
# code_article           object
# designation_article    object
# Item Category Code        str
# company                   str
# dtype: object
# Document No_            0
# Quantity                0
# code_article            0
# designation_article     0
# Item Category Code     39
# company                 0
# dtype: int64
#     Document No_  Quantity code_article  \
# 0  V24-FAC+00002         1    KRDNQ03ZM
# 1  V24-FAC+00003         1  XMGHT2KITLF
# 2  V24-FAC+00004         1   PB3018INZM
#
#                       designation_article Item Category Code company
# 0              MI SMART SPACE HEATER S EU         ACC XIAOMI    LSAT
# 1              Xiaomi Grooming Kit Pro EU         ACC XIAOMI    LSAT
# 2  MI POWER BANK BOOST PRO 30000mAh (18W)         ACC XIAOMI    LSAT
#
# --- gps ---
# (325, 4)
# lat           float64
# lng           float64
# clientCode        str
# company           str
# dtype: object
# lat           0
# lng           0
# clientCode    0
# company       0
# dtype: int64
#          lat        lng clientCode company
# 0  35.819893  10.592401  CLT001977    LSAT
# 1  32.928026  10.448577  CLT007994    LSAT
# 2  34.751730  10.775403  CLT011029    LSAT
